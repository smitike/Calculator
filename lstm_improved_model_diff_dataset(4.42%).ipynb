# %% [markdown]
# <a href="https://colab.research.google.com/github/smitike/Calculator/blob/main/lstm_improved_model_diff_dataset(4.42%25).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import all the required libraries
#
# ---

# %%
import pandas as pd
import datetime as dt
from datetime import date
import matplotlib.pyplot as plt
import yfinance as yf
import numpy as np
import tensorflow as tf

# %%
import yfinance as yf
import pandas as pd

# Define start and end date
START = "2010-01-01"
TODAY = "2023-01-01"

def load_data(ticker):
    data = yf.download(ticker, START, TODAY)
    data.reset_index(inplace=True)
    return data

data = load_data('TCS.NS')
df=data
df.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price                       Date   Adj Close       Close        High  \
# Ticker                                TCS.NS      TCS.NS      TCS.NS
# 0      2010-01-04 00:00:00+00:00  295.029663  375.825012  379.450012
# 1      2010-01-05 00:00:00+00:00  295.108032  375.924988  379.774994
# 2      2010-01-06 00:00:00+00:00  288.435547  367.424988  376.100006
# 3      2010-01-07 00:00:00+00:00  280.408722  357.200012  369.700012
# 4      2010-01-08 00:00:00+00:00  274.677917  349.899994  359.250000
#
# Price          Low        Open   Volume
# Ticker      TCS.NS      TCS.NS   TCS.NS
# 0       374.524994  377.399994  1963682
# 1       373.274994  377.500000  2014488
# 2       366.500000  375.924988  3349176
# 3       355.500000  367.750000  6474892
# 4       348.250000  358.000000  6048178

# %% [markdown]
# # Define start day to fetch the dataset from the yahoo finance library
#
# ---

# %%
START = "2010-01-01"
TODAY = date.today().strftime("%Y-%m-%d")

# Define a function to load the dataset

def load_data(ticker):
    data = yf.download(ticker, START, TODAY)
    data.reset_index(inplace=True)
    return data

# %%
data = load_data('TCS.NS')
df=data
df.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price                       Date   Adj Close       Close        High  \
# Ticker                                TCS.NS      TCS.NS      TCS.NS
# 0      2010-01-04 00:00:00+00:00  289.859131  375.825012  379.450012
# 1      2010-01-05 00:00:00+00:00  289.936279  375.924988  379.774994
# 2      2010-01-06 00:00:00+00:00  283.380493  367.424988  376.100006
# 3      2010-01-07 00:00:00+00:00  275.494507  357.200012  369.700012
# 4      2010-01-08 00:00:00+00:00  269.864136  349.899994  359.250000
#
# Price          Low        Open   Volume
# Ticker      TCS.NS      TCS.NS   TCS.NS
# 0       374.524994  377.399994  1963682
# 1       373.274994  377.500000  2014488
# 2       366.500000  375.924988  3349176
# 3       355.500000  367.750000  6474892
# 4       348.250000  358.000000  6048178

# %%
df = df.drop(['Date', 'Adj Close'], axis = 1)
df.head()
# Out:
# <ipython-input-57-8097d146b7ad>:1: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   df = df.drop(['Date', 'Adj Close'], axis = 1)
# Price        Close        High         Low        Open   Volume
# Ticker      TCS.NS      TCS.NS      TCS.NS      TCS.NS   TCS.NS
# 0       375.825012  379.450012  374.524994  377.399994  1963682
# 1       375.924988  379.774994  373.274994  377.500000  2014488
# 2       367.424988  376.100006  366.500000  375.924988  3349176
# 3       357.200012  369.700012  355.500000  367.750000  6474892
# 4       349.899994  359.250000  348.250000  358.000000  6048178

# %% [markdown]
# Visualizing Closing Price

# %%
plt.figure(figsize=(12, 6))
plt.plot(df['Close'])
plt.title("TCS India Stock Price")
plt.xlabel("Date")
plt.ylabel("Price (INR)")
plt.grid(True)
plt.show()

# %%
df
# Out:
# Price         Close         High          Low         Open   Volume
# Ticker       TCS.NS       TCS.NS       TCS.NS       TCS.NS   TCS.NS
# 0        375.825012   379.450012   374.524994   377.399994  1963682
# 1        375.924988   379.774994   373.274994   377.500000  2014488
# 2        367.424988   376.100006   366.500000   375.924988  3349176
# 3        357.200012   369.700012   355.500000   367.750000  6474892
# 4        349.899994   359.250000   348.250000   358.000000  6048178
# ...             ...          ...          ...          ...      ...
# 3204    3252.899902  3272.000000  3225.050049  3228.350098   870157
# 3205    3259.500000  3273.800049  3231.500000  3269.199951   835883
# 3206    3257.100098  3266.100098  3226.000000  3249.800049   910795
# 3207    3268.750000  3271.500000  3228.000000  3231.100098  1037927
# 3208    3256.699951  3299.000000  3246.199951  3286.050049  1163131
#
# [3209 rows x 5 columns]

# %% [markdown]
# # Plotting moving averages of 100 day
#
# ---

# %%
ma100 = df.Close.rolling(100).mean()
ma100
# Out:
# Ticker       TCS.NS
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# ...             ...
# 3204    3227.688494
# 3205    3227.295493
# 3206    3226.948494
# 3207    3226.240994
# 3208    3225.258494
#
# [3209 rows x 1 columns]

# %%
plt.figure(figsize = (12,6))
plt.plot(df.Close)
plt.plot(ma100, 'r')
plt.grid(True)
plt.title('Graph Of Moving Averages Of 100 Days')
# Out:
# Text(0.5, 1.0, 'Graph Of Moving Averages Of 100 Days')

# %% [markdown]
# # Defining 200 days moving averages and plotting comparision graph with 100 days moving averages
#
# ---

# %%
ma200 = df.Close.rolling(200).mean()
ma200
# Out:
# Ticker       TCS.NS
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# ...             ...
# 3204    3320.515244
# 3205    3318.812994
# 3206    3316.935494
# 3207    3315.174495
# 3208    3313.462245
#
# [3209 rows x 1 columns]

# %%
plt.figure(figsize = (12,6))
plt.plot(df.Close)
plt.plot(ma100, 'r')
plt.plot(ma200, 'g')
plt.grid(True)
plt.title('Comparision Of 100 Days And 200 Days Moving Averages')
# Out:
# Text(0.5, 1.0, 'Comparision Of 100 Days And 200 Days Moving Averages')

# %%
df.shape
# Out:
# (3209, 5)

# %% [markdown]
# # Spliting the dataset into training (70%) and testing (30%) set

# %%
# Splitting data into training and testing

train = pd.DataFrame(data[0:int(len(data)*0.70)])
test = pd.DataFrame(data[int(len(data)*0.70): int(len(data))])

print(train.shape)
print(test.shape)
# Out:
# (2246, 7)
# (963, 7)

# %%
train.head()
# Out:
# Price                       Date   Adj Close       Close        High  \
# Ticker                                TCS.NS      TCS.NS      TCS.NS
# 0      2010-01-04 00:00:00+00:00  295.029663  375.825012  379.450012
# 1      2010-01-05 00:00:00+00:00  295.108032  375.924988  379.774994
# 2      2010-01-06 00:00:00+00:00  288.435547  367.424988  376.100006
# 3      2010-01-07 00:00:00+00:00  280.408722  357.200012  369.700012
# 4      2010-01-08 00:00:00+00:00  274.677917  349.899994  359.250000
#
# Price          Low        Open   Volume
# Ticker      TCS.NS      TCS.NS   TCS.NS
# 0       374.524994  377.399994  1963682
# 1       373.274994  377.500000  2014488
# 2       366.500000  375.924988  3349176
# 3       355.500000  367.750000  6474892
# 4       348.250000  358.000000  6048178

# %%
test.head()
# Out:
# Price                       Date    Adj Close        Close         High  \
# Ticker                                 TCS.NS       TCS.NS       TCS.NS
# 2246   2019-02-07 00:00:00+00:00  1907.494019  2082.899902  2097.949951
# 2247   2019-02-08 00:00:00+00:00  1887.804321  2061.399902  2089.500000
# 2248   2019-02-11 00:00:00+00:00  1891.925537  2065.899902  2096.000000
# 2249   2019-02-12 00:00:00+00:00  1878.829956  2051.600098  2070.000000
# 2250   2019-02-14 00:00:00+00:00  1872.419312  2044.599976  2075.000000
#
# Price           Low         Open   Volume
# Ticker       TCS.NS       TCS.NS   TCS.NS
# 2246    2067.000000  2074.750000  1339945
# 2247    2051.000000  2075.000000  1684474
# 2248    2048.899902  2060.000000  1778730
# 2249    2018.000000  2070.000000  2422903
# 2250    2033.050049  2060.050049  1724085

# %% [markdown]
# # Using MinMax scaler for normalization of the dataset
#
# ---

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0,1))

# %%
train_close = train.iloc[:, 4:5].values
test_close = test.iloc[:, 4:5].values

# %%
data_training_array = scaler.fit_transform(train_close)
data_training_array
# Out:
# array([[0.01726447],
#        [0.01658796],
#        [0.01292129],
#        ...,
#        [0.90942911],
#        [0.91213515],
#        [0.91919791]])

# %%
x_train = []
y_train = []

for i in range(100, data_training_array.shape[0]):
    x_train.append(data_training_array[i-100: i])
    y_train.append(data_training_array[i, 0])

x_train, y_train = np.array(x_train), np.array(y_train)

# %%
x_train.shape
# Out:
# (2146, 100, 1)

# %% [markdown]
# # ML Model (LSTM)
#
# ---

# %%
from tensorflow.keras.layers import Dense, Dropout, LSTM
from tensorflow.keras.models import Sequential

# %%
from tensorflow.keras.layers import Attention

# %%
model = Sequential()
model.add(LSTM(units = 50, activation = 'relu', return_sequences=True
              ,input_shape = (x_train.shape[1], 1)))
model.add(Dropout(0.1))


model.add(LSTM(units = 60, activation = 'relu', return_sequences=True))
model.add(Dropout(0.1))


model.add(LSTM(units = 80, activation = 'relu', return_sequences=True))
model.add(Dropout(0.1))


model.add(LSTM(units = 120, activation = 'relu'))
model.add(Dropout(0.1))

# Add Attention layer
# attention_output = Attention()([model.output, model.output])  # Self-attention on LSTM output
# model.add(Dense(units=1))

# # Compile the model
# model.compile(optimizer='adam', loss='mean_squared_error', metrics=[tf.keras.metrics.MeanAbsoluteError()])

model.add(Dense(units = 1))
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.summary()
# Out:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm_24 (LSTM)                       │ (None, 100, 50)             │          10,400 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_24 (Dropout)                 │ (None, 100, 50)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_25 (LSTM)                       │ (None, 100, 60)             │          26,640 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_25 (Dropout)                 │ (None, 100, 60)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_26 (LSTM)                       │ (None, 100, 80)             │          45,120 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_26 (Dropout)                 │ (None, 100, 80)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_27 (LSTM)                       │ (None, 120)                 │          96,480 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_27 (Dropout)                 │ (None, 120)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 1)                   │             121 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 178,761 (698.29 KB)
#  Trainable params: 178,761 (698.29 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# # Training the model
#
# ---

# %%
import tensorflow as tf
model.compile(optimizer = 'adam', loss = 'mean_squared_error', metrics=[tf.keras.metrics.MeanAbsoluteError()])
model.fit(x_train, y_train,epochs = 100)
# Out:
# Epoch 1/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 19s 133ms/step - loss: 0.0700 - mean_absolute_error: 0.1917
# Epoch 2/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 9s 45ms/step - loss: 0.0022 - mean_absolute_error: 0.0332
# Epoch 3/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 0.0019 - mean_absolute_error: 0.0313
# Epoch 4/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 0.0017 - mean_absolute_error: 0.0303
# Epoch 5/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - loss: 0.0018 - mean_absolute_error: 0.0301
# Epoch 6/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 45ms/step - loss: 0.0017 - mean_absolute_error: 0.0291
# Epoch 7/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 44ms/step - loss: 0.0016 - mean_absolute_error: 0.0288
# Epoch 8/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 45ms/step - loss: 0.0017 - mean_absolute_error: 0.0295
# Epoch 9/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 44ms/step - loss: 0.0015 - mean_absolute_error: 0.0278
# Epoch 10/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 49ms/step - loss: 0.0016 - mean_absolute_error: 0.0285
# Epoch 11/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 44ms/step - loss: 0.0017 - mean_absolute_error: 0.0292
# Epoch 12/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 47ms/step - loss: 0.0015 - mean_absolute_error: 0.0276
# Epoch 13/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 45ms/step - loss: 0.0014 - mean_absolute_error: 0.0266
# Epoch 14/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 0.0015 - mean_absolute_error: 0.0270
# Epoch 15/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 6s 49ms/step - loss: 0.0013 - mean_absolute_error: 0.0265
# Epoch 16/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 43ms/step - loss: 0.0014 - mean_absolute_error: 0.0286
# Epoch 17/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 45ms/step - loss: 0.0014 - mean_absolute_error: 0.0268
# Epoch 18/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 44ms/step - loss: 0.0011 - mean_absolute_error: 0.0245
# Epoch 19/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 0.0013 - mean_absolute_error: 0.0255
# Epoch 20/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - loss: 0.0012 - mean_absolute_error: 0.0248
# Epoch 21/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - loss: 0.0011 - mean_absolute_error: 0.0240
# Epoch 22/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 0.0011 - mean_absolute_error: 0.0240
# Epoch 23/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 0.0010 - mean_absolute_error: 0.0226
# Epoch 24/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 47ms/step - loss: 9.4718e-04 - mean_absolute_error: 0.0225
# Epoch 25/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 45ms/step - loss: 0.0013 - mean_absolute_error: 0.0260
# Epoch 26/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 44ms/step - loss: 0.0013 - mean_absolute_error: 0.0265
# Epoch 27/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 46ms/step - loss: 9.0550e-04 - mean_absolute_error: 0.0223
# Epoch 28/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 44ms/step - loss: 0.0019 - mean_absolute_error: 0.0321
# Epoch 29/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 49ms/step - loss: 9.0440e-04 - mean_absolute_error: 0.0219
# Epoch 30/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 9.1140e-04 - mean_absolute_error: 0.0225
# Epoch 31/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 45ms/step - loss: 8.6814e-04 - mean_absolute_error: 0.0213
# Epoch 32/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 50ms/step - loss: 0.0011 - mean_absolute_error: 0.0236
# Epoch 33/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 8.5871e-04 - mean_absolute_error: 0.0211
# Epoch 34/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 45ms/step - loss: 8.8335e-04 - mean_absolute_error: 0.0218
# Epoch 35/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - loss: 7.8955e-04 - mean_absolute_error: 0.0210
# Epoch 36/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 3s 47ms/step - loss: 0.0011 - mean_absolute_error: 0.0248
# Epoch 37/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 45ms/step - loss: 7.9856e-04 - mean_absolute_error: 0.0203
# Epoch 38/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 49ms/step - loss: 7.7172e-04 - mean_absolute_error: 0.0203
# Epoch 39/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - loss: 9.2324e-04 - mean_absolute_error: 0.0228
# Epoch 40/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 0.0011 - mean_absolute_error: 0.0236
# Epoch 41/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 7.9038e-04 - mean_absolute_error: 0.0208
# Epoch 42/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 6s 50ms/step - loss: 7.4579e-04 - mean_absolute_error: 0.0199
# Epoch 43/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 9.3005e-04 - mean_absolute_error: 0.0222
# Epoch 44/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 45ms/step - loss: 7.5607e-04 - mean_absolute_error: 0.0203
# Epoch 45/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 48ms/step - loss: 6.6799e-04 - mean_absolute_error: 0.0189
# Epoch 46/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 6.7581e-04 - mean_absolute_error: 0.0186
# Epoch 47/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 9.2687e-04 - mean_absolute_error: 0.0221
# Epoch 48/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - loss: 6.7635e-04 - mean_absolute_error: 0.0193
# Epoch 49/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - loss: 7.7430e-04 - mean_absolute_error: 0.0200
# Epoch 50/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 6.0706e-04 - mean_absolute_error: 0.0184
# Epoch 51/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 8.1686e-04 - mean_absolute_error: 0.0208
# Epoch 52/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - loss: 7.0761e-04 - mean_absolute_error: 0.0193
# Epoch 53/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 46ms/step - loss: 6.4088e-04 - mean_absolute_error: 0.0188
# Epoch 54/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 45ms/step - loss: 6.6943e-04 - mean_absolute_error: 0.0188
# Epoch 55/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 50ms/step - loss: 7.1079e-04 - mean_absolute_error: 0.0196
# Epoch 56/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 6.1938e-04 - mean_absolute_error: 0.0184
# Epoch 57/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 45ms/step - loss: 5.9159e-04 - mean_absolute_error: 0.0177
# Epoch 58/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - loss: 5.9164e-04 - mean_absolute_error: 0.0179
# Epoch 59/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 44ms/step - loss: 6.6113e-04 - mean_absolute_error: 0.0192
# Epoch 60/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 47ms/step - loss: 7.2957e-04 - mean_absolute_error: 0.0199
# Epoch 61/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - loss: 6.1638e-04 - mean_absolute_error: 0.0185
# Epoch 62/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 6.9757e-04 - mean_absolute_error: 0.0187
# Epoch 63/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 6.0333e-04 - mean_absolute_error: 0.0178
# Epoch 64/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 6.2686e-04 - mean_absolute_error: 0.0183
# Epoch 65/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 45ms/step - loss: 6.4955e-04 - mean_absolute_error: 0.0188
# Epoch 66/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 6.5998e-04 - mean_absolute_error: 0.0186
# Epoch 67/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 3s 47ms/step - loss: 5.8712e-04 - mean_absolute_error: 0.0180
# Epoch 68/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 4s 53ms/step - loss: 5.9288e-04 - mean_absolute_error: 0.0176
# Epoch 69/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 4s 43ms/step - loss: 4.8821e-04 - mean_absolute_error: 0.0163
# Epoch 70/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 6.6490e-04 - mean_absolute_error: 0.0187
# Epoch 71/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 6s 50ms/step - loss: 6.6121e-04 - mean_absolute_error: 0.0191
# Epoch 72/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 44ms/step - loss: 5.9273e-04 - mean_absolute_error: 0.0177
# Epoch 73/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 5.4804e-04 - mean_absolute_error: 0.0173
# Epoch 74/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - loss: 5.4032e-04 - mean_absolute_error: 0.0169
# Epoch 75/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 45ms/step - loss: 4.7258e-04 - mean_absolute_error: 0.0160
# Epoch 76/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 5.0600e-04 - mean_absolute_error: 0.0167
# Epoch 77/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 6s 49ms/step - loss: 5.6156e-04 - mean_absolute_error: 0.0176
# Epoch 78/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 44ms/step - loss: 4.9856e-04 - mean_absolute_error: 0.0165
# Epoch 79/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 45ms/step - loss: 5.8441e-04 - mean_absolute_error: 0.0180
# Epoch 80/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 3s 50ms/step - loss: 5.1721e-04 - mean_absolute_error: 0.0168
# Epoch 81/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 5.9124e-04 - mean_absolute_error: 0.0179
# Epoch 82/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 45ms/step - loss: 5.3979e-04 - mean_absolute_error: 0.0171
# Epoch 83/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - loss: 6.0433e-04 - mean_absolute_error: 0.0186
# Epoch 84/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 45ms/step - loss: 8.8547e-04 - mean_absolute_error: 0.0208
# Epoch 85/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 45ms/step - loss: 5.8280e-04 - mean_absolute_error: 0.0177
# Epoch 86/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - loss: 4.4847e-04 - mean_absolute_error: 0.0155
# Epoch 87/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 44ms/step - loss: 4.9858e-04 - mean_absolute_error: 0.0166
# Epoch 88/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 45ms/step - loss: 4.6198e-04 - mean_absolute_error: 0.0158
# Epoch 89/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 45ms/step - loss: 5.3396e-04 - mean_absolute_error: 0.0167
# Epoch 90/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 45ms/step - loss: 6.1632e-04 - mean_absolute_error: 0.0186
# Epoch 91/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - loss: 4.3767e-04 - mean_absolute_error: 0.0156
# Epoch 92/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 44ms/step - loss: 5.9551e-04 - mean_absolute_error: 0.0178
# Epoch 93/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 4.8126e-04 - mean_absolute_error: 0.0166
# Epoch 94/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - loss: 5.2791e-04 - mean_absolute_error: 0.0169
# Epoch 95/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 45ms/step - loss: 4.7207e-04 - mean_absolute_error: 0.0163
# Epoch 96/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 45ms/step - loss: 4.7253e-04 - mean_absolute_error: 0.0165
# Epoch 97/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 3s 47ms/step - loss: 4.6741e-04 - mean_absolute_error: 0.0162
# Epoch 98/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 45ms/step - loss: 5.2945e-04 - mean_absolute_error: 0.0169
# Epoch 99/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 4.2609e-04 - mean_absolute_error: 0.0154
# Epoch 100/100
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 6s 52ms/step - loss: 4.7526e-04 - mean_absolute_error: 0.0158

# %%
model.save('keras_model.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
test_close.shape
# Out:
# (963, 1)

# %%
past_100_days = pd.DataFrame(train_close[-100:])

# %%
test_df = pd.DataFrame(test_close)

# %% [markdown]
# **Defining the final dataset for testing by including last 100 coloums of the training dataset to get the prediction from the 1st column of the testing dataset.**
#
# ---

# %%
# final_df = past_100_days.append(test_df, ignore_index = True)
final_df = pd.concat([past_100_days, test_df], ignore_index=True)

# %%
final_df.head()
# Out:
#              0
# 0  2042.199951
# 1  2040.000000
# 2  2018.150024
# 3  2054.550049
# 4  2057.600098

# %%
input_data = scaler.fit_transform(final_df)
input_data
# Out:
# array([[0.21671817],
#        [0.21582892],
#        [0.2069969 ],
#        ...,
#        [0.69522423],
#        [0.69603265],
#        [0.70338929]])

# %%
input_data.shape
# Out:
# (1063, 1)

# %% [markdown]
# # Testing the model
#
# ---

# %%
x_test = []
y_test = []
for i in range(100, input_data.shape[0]):
   x_test.append(input_data[i-100: i])
   y_test.append(input_data[i, 0])

# %%
x_test, y_test = np.array(x_test), np.array(y_test)
print(x_test.shape)
print(y_test.shape)
# Out:
# (963, 100, 1)
# (963,)

# %% [markdown]
# SELAM - Ensure that both the training and testing data are normalized before feeding them into the model:

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
x_train = scaler.fit_transform(x_train.reshape(-1, 1)).reshape(x_train.shape)
x_test = scaler.transform(x_test.reshape(-1, 1)).reshape(x_test.shape)

# %% [markdown]
# # Making prediction and plotting the graph of predicted vs actual values
#
# ---

# %%
# Making predictions

y_pred = model.predict(x_test)
# Out:
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/
#        0.74550815, 0.78295844, 0.69684108, 0.71302978, 0.71179692,
#        0.71527318, 0.6661412 , 0.67685282, 0.69651769, 0.71961846,
#        0.73524121, 0.74132462, 0.74385094, 0.77816849, 0.75632082,
#        0.74777178, 0.74393176, 0.7465996 , 0.74615493, 0.6816629 ,
#        0.67448814, 0.68511893, 0.65765275, 0.61351284, 0.63176296,
#        0.65456047, 0.67784312, 0.69399136, 0.71604114, 0.72776329,
#        0.71406054, 0.71341377, 0.70694638, 0.70575397, 0.69484025,
#        0.68752397, 0.6856242 , 0.71100872, 0.70492532, 0.6467188 ,
#        0.63631035, 0.61801976, 0.59053335, 0.58487438, 0.60965259,
#        0.61601893, 0.64350534, 0.66209909, 0.66187675, 0.66414038,
#        0.64287879, 0.64833565, 0.68538163, 0.71503061, 0.71341377,
#        0.71367646, 0.71585927, 0.72810691, 0.74736757, 0.73968754,
#        0.73928333, 0.75547203, 0.75797813, 0.76050445, 0.75387542,
#        0.75019705, 0.75393601, 0.74429552, 0.71300955, 0.70500614,
#        0.69067685, 0.6915055 , 0.63661351, 0.66131089, 0.65278198,
#        0.65249905, 0.64924513, 0.64686032, 0.64510196, 0.66858671,
#        0.67198205, 0.69482002, 0.69482002, 0.64987168, 0.64429353,
#        0.60387234, 0.59894098, 0.6159987 , 0.60312451, 0.59550518,
#        0.59538389, 0.57400112, 0.59417126, 0.5957881 , 0.59983022,
#        0.58370221, 0.59336283, 0.61316922, 0.64124171, 0.62735709,
#        0.6058934 , 0.62543709, 0.62895371, 0.62503287, 0.63257139,
#        0.63275326, 0.6558338 , 0.64914407, 0.64631459, 0.65520725,
#        0.66652519, 0.66496893, 0.65817825, 0.66248307, 0.67574124,
#        0.68610923, 0.69362761, 0.68269366, 0.67103211, 0.68273412,
#        0.68538163, 0.67258836, 0.70696661, 0.72877382, 0.72190222,
#        0.73380624, 0.73231067, 0.73362436, 0.71422219, 0.70704743,
#        0.721498  , 0.72849089, 0.74453808, 0.75163202, 0.7586855 ,
#        0.7554518 , 0.77364134, 0.77081186, 0.76838658, 0.75262232,
#        0.74696335, 0.74108205, 0.71557634, 0.69930681, 0.71212031,
#        0.74166814, 0.72471147, 0.69490084, 0.68249156, 0.67002158,
#        0.7008832 , 0.70294472, 0.69158632, 0.69484025, 0.6974474 ,
#        0.69522423, 0.69603265, 0.70338929])

# %%
y_pred
# Out:
# array([[0.18681605],
#        [0.19156696],
#        [0.1966207 ],
#        [0.20134383],
#        [0.20474276],
#        [0.20679852],
#        [0.20748211],
#        [0.2063876 ],
#        [0.20282969],
#        [0.19669756],
#        [0.18891183],
#        [0.18113872],
#        [0.1750904 ],
#        [0.1724143 ],
#        [0.17390443],
#        [0.17775145],
#        [0.1824139 ],
#        [0.18704532],
#        [0.19124658],
#        [0.19494838],
#        [0.19825289],
#        [0.2010411 ],
#        [0.20319127],
#        [0.20422037],
#        [0.20416315],
#        [0.20352866],
#        [0.20326307],
#        [0.20335658],
#        [0.203735  ],
#        [0.20395792],
#        [0.20375438],
#        [0.20277813],
#        [0.20120406],
#        [0.19974402],
#        [0.1994205 ],
#        [0.20108074],
#        [0.20496692],
#        [0.20912868],
#        [0.21245031],
#        [0.21485573],
#        [0.2170741 ],
#        [0.21882132],
#        [0.2193064 ],
#        [0.21833542],
#        [0.21716742],
#        [0.21801664],
#        [0.2222577 ],
#        [0.23161294],
#        [0.2450738 ],
#        [0.25921372],
#        [0.271614  ],
#        [0.28178394],
#        [0.29084995],
#        [0.29767704],
#        [0.2989194 ],
#        [0.29575115],
#        [0.29050905],
#        [0.28446215],
#        [0.2789085 ],
#        [0.27446458],
#        [0.27109396],
#        [0.26645878],
#        [0.259893  ],
#        [0.2522968 ],
#        [0.2453222 ],
#        [0.23880386],
#        [0.23405762],
#        [0.23090613],
#        [0.22824334],
#        [0.22524482],
#        [0.22212484],
#        [0.21936467],
#        [0.21792701],
#        [0.21895538],
#        [0.2242124 ],
#        [0.23657458],
#        [0.25319612],
#        [0.26781708],
#        [0.2769895 ],
#        [0.28259233],
#        [0.28795606],
#        [0.29343995],
#        [0.29909664],
#        [0.30365965],
#        [0.30658558],
#        [0.30737624],
#        [0.30696356],
#        [0.3050184 ],
#        [0.30320555],
#        [0.30278096],
#        [0.3037015 ],
#        [0.30524796],
#        [0.30632257],
#        [0.30590183],
#        [0.303773  ],
#        [0.3011764 ],
#        [0.29968908],
#        [0.29967803],
#        [0.29831836],
#        [0.29544544],
#        [0.2913106 ],
#        [0.28493422],
#        [0.27628797],
#        [0.26616314],
#        [0.25705308],
#        [0.25020722],
#        [0.2455407 ],
#        [0.24144956],
#        [0.23724069],
#        [0.23323125],
#        [0.2306164 ],
#        [0.22916897],
#        [0.22884561],
#        [0.22947417],
#        [0.23097058],
#        [0.23382717],
#        [0.23942539],
#        [0.2486615 ],
#        [0.25952557],
#        [0.27056354],
#        [0.28087038],
#        [0.28904128],
#        [0.29481947],
#        [0.29925168],
#        [0.30074546],
#        [0.29909703],
#        [0.29545638],
#        [0.2912527 ],
#        [0.2876022 ],
#        [0.28589243],
#        [0.28606388],
#        [0.2889562 ],
#        [0.29403594],
#        [0.29981694],
#        [0.304007  ],
#        [0.3059485 ],
#        [0.3059047 ],
#        [0.305357  ],
#        [0.30487955],
#        [0.30363536],
#        [0.30118448],
#        [0.2979698 ],
#        [0.29433274],
#        [0.290447  ],
#        [0.28603625],
#        [0.28130928],
#        [0.2760691 ],
#        [0.27088806],
#        [0.26532587],
#        [0.2580572 ],
#        [0.24847528],
#        [0.23831093],
#        [0.2294903 ],
#        [0.22341359],
#        [0.21988347],
#        [0.21838276],
#        [0.21783793],
#        [0.21769598],
#        [0.21789214],
#        [0.21805625],
#        [0.21747881],
#        [0.2157611 ],
#        [0.21201827],
#        [0.20749843],
#        [0.20439675],
#        [0.20340571],
#        [0.203921  ],
#        [0.20570073],
#        [0.20862885],
#        [0.2124439 ],
#        [0.2169021 ],
#        [0.22195426],
#        [0.22871272],
#        [0.23815697],
#        [0.2517002 ],
#        [0.26863366],
#        [0.28416383],
#        [0.2944966 ],
#        [0.298524  ],
#        [0.29815125],
#        [0.29565856],
#        [0.29169646],
#        [0.28632134],
#        [0.27973148],
#        [0.27405724],
#        [0.272042  ],
#        [0.27332577],
#        [0.274312  ],
#        [0.27300182],
#        [0.2694366 ],
#        [0.2627936 ],
#        [0.25391507],
#        [0.24429257],
#        [0.23544522],
#        [0.22854616],
#        [0.22359976],
#        [0.21969211],
#        [0.21621385],
#        [0.21381323],
#        [0.21324739],
#        [0.21522784],
#        [0.21830752],
#        [0.21979734],
#        [0.21903314],
#        [0.2163106 ],
#        [0.21302073],
#        [0.21167046],
#        [0.21377072],
#        [0.22090572],
#        [0.23556603],
#        [0.25581405],
#        [0.27563876],
#        [0.29095072],
#        [0.2996325 ],
#        [0.30182844],
#        [0.2996192 ],
#        [0.2953168 ],
#        [0.29064816],
#        [0.2865148 ],
#        [0.28392303],
#        [0.28405082],
#        [0.2864221 ],
#        [0.29031524],
#        [0.29474074],
#        [0.29847884],
#        [0.29992196],
#        [0.29953372],
#        [0.29821125],
#        [0.29747692],
#        [0.29768345],
#        [0.29651812],
#        [0.29416493],
#        [0.29161963],
#        [0.29010743],
#        [0.28952503],
#        [0.28937775],
#        [0.28894284],
#        [0.2881119 ],
#        [0.28635195],
#        [0.2824305 ],
#        [0.2760762 ],
#        [0.26748857],
#        [0.2589033 ],
#        [0.25243425],
#        [0.24904852],
#        [0.2486725 ],
#        [0.2517878 ],
#        [0.25766584],
#        [0.26537004],
#        [0.27315217],
#        [0.28029555],
#        [0.2859116 ],
#        [0.2897465 ],
#        [0.29063737],
#        [0.28882146],
#        [0.28484738],
#        [0.27910286],
#        [0.27152866],
#        [0.26066634],
#        [0.24820504],
#        [0.23614925],
#        [0.22598341],
#        [0.21967545],
#        [0.21723029],
#        [0.21476069],
#        [0.21061704],
#        [0.20227219],
#        [0.1838231 ],
#        [0.15674056],
#        [0.12598479],
#        [0.09824297],
#        [0.07661971],
#        [0.06347123],
#        [0.05726379],
#        [0.05672063],
#        [0.06009112],
#        [0.06525132],
#        [0.07082526],
#        [0.07620338],
#        [0.08138305],
#        [0.08541003],
#        [0.08726402],
#        [0.08799854],
#        [0.08801663],
#        [0.08776006],
#        [0.08783022],
#        [0.08813085],
#        [0.08736172],
#        [0.08730033],
#        [0.08988923],
#        [0.09348086],
#        [0.09665632],
#        [0.09964305],
#        [0.10334399],
#        [0.10789287],
#        [0.11294632],
#        [0.11824715],
#        [0.12432952],
#        [0.13079023],
#        [0.13722263],
#        [0.1430449 ],
#        [0.1478582 ],
#        [0.15122718],
#        [0.15341397],
#        [0.15484655],
#        [0.1561544 ],
#        [0.15696469],
#        [0.15658523],
#        [0.15510526],
#        [0.1537596 ],
#        [0.15383956],
#        [0.15583669],
#        [0.15969326],
#        [0.16402753],
#        [0.16828215],
#        [0.17239994],
#        [0.17613739],
#        [0.17949267],
#        [0.18300329],
#        [0.18686451],
#        [0.19134583],
#        [0.19616926],
#        [0.20114017],
#        [0.20602247],
#        [0.21084332],
#        [0.2149964 ],
#        [0.21678527],
#        [0.21612653],
#        [0.2143014 ],
#        [0.21236947],
#        [0.21088602],
#        [0.21017015],
#        [0.20993908],
#        [0.2097619 ],
#        [0.20993581],
#        [0.2101136 ],
#        [0.21034335],
#        [0.2122091 ],
#        [0.21573082],
#        [0.22062065],
#        [0.22673537],
#        [0.23684974],
#        [0.2524309 ],
#        [0.27092582],
#        [0.2871068 ],
#        [0.29722127],
#        [0.3006352 ],
#        [0.30035326],
#        [0.2974312 ],
#        [0.29387707],
#        [0.29233316],
#        [0.2922184 ],
#        [0.29265755],
#        [0.2934852 ],
#        [0.29388514],
#        [0.29297295],
#        [0.29074347],
#        [0.28814036],
#        [0.28781536],
#        [0.29161596],
#        [0.29931882],
#        [0.30802447],
#        [0.31353042],
#        [0.31443584],
#        [0.3130487 ],
#        [0.31175852],
#        [0.31239223],
#        [0.31412405],
#        [0.31567612],
#        [0.31515038],
#        [0.31288466],
#        [0.3094306 ],
#        [0.30607465],
#        [0.3040934 ],
#        [0.30389062],
#        [0.30451763],
#        [0.3052759 ],
#        [0.30541977],
#        [0.30509493],
#        [0.3040174 ],
#        [0.30344018],
#        [0.30354142],
#        [0.30379847],
#        [0.30441552],
#        [0.30533844],
#        [0.3074683 ],
#        [0.3102018 ],
#        [0.31349933],
#        [0.31871367],
#        [0.32464176],
#        [0.32965115],
#        [0.33282042],
#        [0.3369099 ],
#        [0.3455065 ],
#        [0.35871378],
#        [0.37102485],
#        [0.37746447],
#        [0.37883073],
#        [0.37766862],
#        [0.3732525 ],
#        [0.36545992],
#        [0.35633126],
#        [0.34855574],
#        [0.34648705],
#        [0.35234198],
#        [0.36507168],
#        [0.38363355],
#        [0.40553796],
#        [0.42875156],
#        [0.4523412 ],
#        [0.4744841 ],
#        [0.49398243],
#        [0.5101875 ],
#        [0.52102387],
#        [0.52016973],
#        [0.5102793 ],
#        [0.4955997 ],
#        [0.48243153],
#        [0.47021282],
#        [0.4585702 ],
#        [0.4525212 ],
#        [0.45307332],
#        [0.4531025 ],
#        [0.4493276 ],
#        [0.4433723 ],
#        [0.43990576],
#        [0.4383319 ],
#        [0.43791538],
#        [0.43896908],
#        [0.44552088],
#        [0.45691276],
#        [0.46982402],
#        [0.47468036],
#        [0.47120687],
#        [0.46551287],
#        [0.4591811 ],
#        [0.45631075],
#        [0.4562568 ],
#        [0.45339575],
#        [0.45010975],
#        [0.4481159 ],
#        [0.45127085],
#        [0.46076742],
#        [0.47160906],
#        [0.47834012],
#        [0.47846392],
#        [0.47090667],
#        [0.4661264 ],
#        [0.46809518],
#        [0.47390813],
#        [0.4799829 ],
#        [0.4864717 ],
#        [0.49542463],
#        [0.5051927 ],
#        [0.51149464],
#        [0.5115391 ],
#        [0.5071844 ],
#        [0.50224376],
#        [0.5037098 ],
#        [0.51158893],
#        [0.5179987 ],
#        [0.52259505],
#        [0.528942  ],
#        [0.5377351 ],
#        [0.5479902 ],
#        [0.55828345],
#        [0.5644214 ],
#        [0.5591248 ],
#        [0.5504782 ],
#        [0.55045414],
#        [0.56044185],
#        [0.57695067],
#        [0.59384847],
#        [0.60929465],
#        [0.6248796 ],
#        [0.6405258 ],
#        [0.653883  ],
#        [0.6612747 ],
#        [0.6694434 ],
#        [0.6777729 ],
#        [0.6876404 ],
#        [0.698972  ],
#        [0.7086319 ],
#        [0.71172106],
#        [0.71383476],
#        [0.7103125 ],
#        [0.6983876 ],
#        [0.6776638 ],
#        [0.6528518 ],
#        [0.6409093 ],
#        [0.6473236 ],
#        [0.66365623],
#        [0.67733574],
#        [0.6859937 ],
#        [0.6908984 ],
#        [0.6919066 ],
#        [0.6940683 ],
#        [0.6964761 ],
#        [0.69071746],
#        [0.67780674],
#        [0.6600504 ],
#        [0.64219904],
#        [0.6284386 ],
#        [0.6150106 ],
#        [0.60628855],
#        [0.59947455],
#        [0.60028696],
#        [0.5961516 ],
#        [0.58994836],
#        [0.59071076],
#        [0.60088414],
#        [0.6155726 ],
#        [0.6282288 ],
#        [0.63420856],
#        [0.63301706],
#        [0.63627195],
#        [0.6406957 ],
#        [0.64311314],
#        [0.64509   ],
#        [0.64906526],
#        [0.6412715 ],
#        [0.6286994 ],
#        [0.6198919 ],
#        [0.62474215],
#        [0.63799155],
#        [0.6477003 ],
#        [0.64870024],
#        [0.64624023],
#        [0.6506243 ],
#        [0.6606914 ],
#        [0.6727092 ],
#        [0.686074  ],
#        [0.6992935 ],
#        [0.7118187 ],
#        [0.7240393 ],
#        [0.7244023 ],
#        [0.7043086 ],
#        [0.67670107],
#        [0.66175807],
#        [0.66134083],
#        [0.6661242 ],
#        [0.66841567],
#        [0.66522694],
#        [0.66023374],
#        [0.6588948 ],
#        [0.6622287 ],
#        [0.6662278 ],
#        [0.6577246 ],
#        [0.6427752 ],
#        [0.6314032 ],
#        [0.6312026 ],
#        [0.640347  ],
#        [0.65417445],
#        [0.6686481 ],
#        [0.67594135],
#        [0.67146623],
#        [0.65906227],
#        [0.64521444],
#        [0.64109945],
#        [0.6440351 ],
#        [0.6468105 ],
#        [0.6477983 ],
#        [0.6497972 ],
#        [0.653664  ],
#        [0.659793  ],
#        [0.66955215],
#        [0.6784116 ],
#        [0.68237823],
#        [0.68157446],
#        [0.67616475],
#        [0.67109644],
#        [0.66875446],
#        [0.6699922 ],
#        [0.6775806 ],
#        [0.68816113],
#        [0.6973228 ],
#        [0.70425963],
#        [0.71294224],
#        [0.720363  ],
#        [0.72416914],
#        [0.7251744 ],
#        [0.7261686 ],
#        [0.72461736],
#        [0.7252998 ],
#        [0.72473323],
#        [0.7254416 ],
#        [0.73361474],
#        [0.7446381 ],
#        [0.7518022 ],
#        [0.75506127],
#        [0.75482094],
#        [0.7476058 ],
#        [0.7401738 ],
#        [0.72960544],
#        [0.7191927 ],
#        [0.7121589 ],
#        [0.7057441 ],
#        [0.7003796 ],
#        [0.69632447],
#        [0.696576  ],
#        [0.7012533 ],
#        [0.7066566 ],
#        [0.70791626],
#        [0.70335436],
#        [0.70235693],
#        [0.70720905],
#        [0.7110461 ],
#        [0.7074412 ],
#        [0.6971524 ],
#        [0.6944035 ],
#        [0.6950247 ],
#        [0.69670343],
#        [0.7043928 ],
#        [0.7163274 ],
#        [0.72891116],
#        [0.7375572 ],
#        [0.74534035],
#        [0.7514415 ],
#        [0.75540864],
#        [0.75634885],
#        [0.7585429 ],
#        [0.767411  ],
#        [0.7807958 ],
#        [0.79692817],
#        [0.8103329 ],
#        [0.82241786],
#        [0.83393407],
#        [0.84276915],
#        [0.8510457 ],
#        [0.85581815],
#        [0.86088073],
#        [0.86589134],
#        [0.8684963 ],
#        [0.87029576],
#        [0.8813617 ],
#        [0.8950683 ],
#        [0.9017477 ],
#        [0.8943974 ],
#        [0.8847014 ],
#        [0.87940955],
#        [0.88793325],
#        [0.905059  ],
#        [0.9220321 ],
#        [0.91821706],
#        [0.90717506],
#        [0.9001874 ],
#        [0.9041382 ],
#        [0.9088689 ],
#        [0.91380155],
#        [0.9090663 ],
#        [0.8941817 ],
#        [0.8790114 ],
#        [0.87715185],
#        [0.87994945],
#        [0.88029337],
#        [0.8873836 ],
#        [0.9014423 ],
#        [0.9168731 ],
#        [0.93458605],
#        [0.91726923],
#        [0.8883152 ],
#        [0.8645077 ],
#        [0.8484534 ],
#        [0.84269655],
#        [0.85090435],
#        [0.85301983],
#        [0.8428031 ],
#        [0.82936156],
#        [0.81597483],
#        [0.8111967 ],
#        [0.8168311 ],
#        [0.8133917 ],
#        [0.8039564 ],
#        [0.79846823],
#        [0.8083526 ],
#        [0.8212091 ],
#        [0.83373404],
#        [0.8374524 ],
#        [0.8354423 ],
#        [0.8288636 ],
#        [0.8162652 ],
#        [0.8119111 ],
#        [0.8207818 ],
#        [0.8330381 ],
#        [0.8366761 ],
#        [0.82477295],
#        [0.8090184 ],
#        [0.79373324],
#        [0.78723264],
#        [0.79099476],
#        [0.7941667 ],
#        [0.79421294],
#        [0.8042675 ],
#        [0.8194623 ],
#        [0.8362293 ],
#        [0.8526077 ],
#        [0.8527174 ],
#        [0.84227717],
#        [0.8421129 ],
#        [0.8424058 ],
#        [0.8420973 ],
#        [0.84444237],
#        [0.8439107 ],
#        [0.83799255],
#        [0.8345525 ],
#        [0.8349848 ],
#        [0.8267391 ],
#        [0.8275893 ],
#        [0.8377973 ],
#        [0.8524642 ],
#        [0.86470246],
#        [0.87077916],
#        [0.8763745 ],
#        [0.87811375],
#        [0.8755827 ],
#        [0.87868345],
#        [0.8852974 ],
#        [0.898528  ],
#        [0.9088737 ],
#        [0.9058715 ],
#        [0.900877  ],
#        [0.9071742 ],
#        [0.91515684],
#        [0.9154351 ],
#        [0.91445756],
#        [0.91437244],
#        [0.9287647 ],
#        [0.94659424],
#        [0.94537985],
#        [0.92551076],
#        [0.9000771 ],
#        [0.87908006],
#        [0.86688185],
#        [0.8536267 ],
#        [0.84869003],
#        [0.8648709 ],
#        [0.8847362 ],
#        [0.9064125 ],
#        [0.92366934],
#        [0.92420554],
#        [0.91328275],
#        [0.8970262 ],
#        [0.8890501 ],
#        [0.89239943],
#        [0.8848368 ],
#        [0.8800068 ],
#        [0.88740385],
#        [0.90290666],
#        [0.91253877],
#        [0.90994775],
#        [0.8956351 ],
#        [0.8704709 ],
#        [0.8462579 ],
#        [0.81918573],
#        [0.7999259 ],
#        [0.79615474],
#        [0.8097795 ],
#        [0.82840157],
#        [0.83783233],
#        [0.82923627],
#        [0.8199687 ],
#        [0.83105624],
#        [0.84917796],
#        [0.86362123],
#        [0.8666836 ],
#        [0.86145246],
#        [0.8599119 ],
#        [0.86539435],
#        [0.86522555],
#        [0.8609973 ],
#        [0.866439  ],
#        [0.8748796 ],
#        [0.8766079 ],
#        [0.87134004],
#        [0.87017214],
#        [0.8736994 ],
#        [0.8797407 ],
#        [0.8848103 ],
#        [0.8879732 ],
#        [0.89357424],
#        [0.8920307 ],
#        [0.8790376 ],
#        [0.86221635],
#        [0.8530909 ],
#        [0.85360944],
#        [0.85947084],
#        [0.84605324],
#        [0.82460916],
#        [0.8079239 ],
#        [0.8149302 ],
#        [0.83283854],
#        [0.84500885],
#        [0.8445287 ],
#        [0.83734214],
#        [0.835459  ],
#        [0.83719885],
#        [0.83109665],
#        [0.8201982 ],
#        [0.8140178 ],
#        [0.80494285],
#        [0.7893976 ],
#        [0.78322184],
#        [0.7830267 ],
#        [0.77995825],
#        [0.7818539 ],
#        [0.7839469 ],
#        [0.78239346],
#        [0.792745  ],
#        [0.77967656],
#        [0.7614932 ],
#        [0.746572  ],
#        [0.7412679 ],
#        [0.7290002 ],
#        [0.7172075 ],
#        [0.7168609 ],
#        [0.7300495 ],
#        [0.74729025],
#        [0.764032  ],
#        [0.7772521 ],
#        [0.7892045 ],
#        [0.7943047 ],
#        [0.78893864],
#        [0.7780378 ],
#        [0.7689065 ],
#        [0.7645595 ],
#        [0.7453199 ],
#        [0.72138226],
#        [0.703074  ],
#        [0.6895315 ],
#        [0.67298216],
#        [0.6597569 ],
#        [0.6600388 ],
#        [0.67376757],
#        [0.6925451 ],
#        [0.7124567 ],
#        [0.7311691 ],
#        [0.7453606 ],
#        [0.7517611 ],
#        [0.7483102 ],
#        [0.73942685],
#        [0.7274779 ],
#        [0.71501875],
#        [0.7059362 ],
#        [0.7103625 ],
#        [0.71948886],
#        [0.71017265],
#        [0.69044614],
#        [0.66730833],
#        [0.6437329 ],
#        [0.62302303],
#        [0.6145086 ],
#        [0.62069064],
#        [0.6362011 ],
#        [0.65518045],
#        [0.6735561 ],
#        [0.6888006 ],
#        [0.69208467],
#        [0.6861626 ],
#        [0.68834305],
#        [0.69885063],
#        [0.71358204],
#        [0.7276281 ],
#        [0.736837  ],
#        [0.74305636],
#        [0.75055575],
#        [0.7551492 ],
#        [0.75537187],
#        [0.7575232 ],
#        [0.76159215],
#        [0.7656609 ],
#        [0.7659439 ],
#        [0.7626344 ],
#        [0.7599654 ],
#        [0.75659174],
#        [0.74297845],
#        [0.7260771 ],
#        [0.7101364 ],
#        [0.7013403 ],
#        [0.68647474],
#        [0.6753695 ],
#        [0.67164546],
#        [0.67393935],
#        [0.67758155],
#        [0.67954665],
#        [0.6793022 ],
#        [0.6858813 ],
#        [0.69640875],
#        [0.70923126],
#        [0.7212262 ],
#        [0.7147659 ],
#        [0.697608  ],
#        [0.6727956 ],
#        [0.64710987],
#        [0.6298661 ],
#        [0.6233293 ],
#        [0.6218946 ],
#        [0.6216947 ],
#        [0.61540735],
#        [0.6118181 ],
#        [0.61347795],
#        [0.61899817],
#        [0.6194025 ],
#        [0.6180446 ],
#        [0.6227386 ],
#        [0.634017  ],
#        [0.6463703 ],
#        [0.6483583 ],
#        [0.6471254 ],
#        [0.64731836],
#        [0.64710283],
#        [0.6483164 ],
#        [0.6499976 ],
#        [0.6562879 ],
#        [0.6634717 ],
#        [0.6674043 ],
#        [0.66986394],
#        [0.6742457 ],
#        [0.6787149 ],
#        [0.6795336 ],
#        [0.6782949 ],
#        [0.6804637 ],
#        [0.68761516],
#        [0.69770557],
#        [0.70305574],
#        [0.69891214],
#        [0.6944164 ],
#        [0.6937902 ],
#        [0.6919446 ],
#        [0.69771993],
#        [0.7108725 ],
#        [0.72615373],
#        [0.7403311 ],
#        [0.7492821 ],
#        [0.7521819 ],
#        [0.74479115],
#        [0.7312586 ],
#        [0.7250744 ],
#        [0.7280712 ],
#        [0.73923874],
#        [0.7534131 ],
#        [0.7664143 ],
#        [0.77316976],
#        [0.77911043],
#        [0.7826698 ],
#        [0.7824917 ],
#        [0.774724  ],
#        [0.7634394 ],
#        [0.75334096],
#        [0.7397127 ],
#        [0.72389054],
#        [0.71708405],
#        [0.7274244 ],
#        [0.7411003 ],
#        [0.7406558 ],
#        [0.7283778 ],
#        [0.7117656 ],
#        [0.7076453 ],
#        [0.7163192 ],
#        [0.7243595 ],
#        [0.7279792 ],
#        [0.72901464],
#        [0.7277793 ],
#        [0.7259563 ]], dtype=float32)

# %%
scaler.scale_
# Out:
# array([1.])

# %%
scale_factor = 1 / 0.00041967  # Replace with your scale factor
y_pred = scaler.inverse_transform(y_pred)
y_test = scaler.inverse_transform(y_test.reshape(-1, 1)).flatten()

# %%
scale_factor = 1/0.00041967
y_pred = y_pred * scale_factor
y_test = y_test * scale_factor

# %%
# y_pred = np.squeeze(y_pred)
plt.figure(figsize = (12,6))
plt.plot(y_test, 'b', label = "Original Price")
# plt.plot(y_pred[:, -1, 0], 'r', label = "Predicted Price") #Selecting the last predicted value from the sequence for each time step.
plt.plot(y_pred, 'r', label = "Predicted Price")
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # Model evaluation

# %% [markdown]
# Calculation of mean absolute error

# %%
from sklearn.metrics import mean_absolute_error

y_pred = y_pred.flatten()
mae = mean_absolute_error(y_test, y_pred)
mae_percentage = (mae / np.mean(y_test)) * 100
print("Mean absolute error on test set: {:.2f}%".format(mae_percentage))
# Out:
# Mean absolute error on test set: 4.42%

# %% [markdown]
# Calculation of R2 score

# %%
from sklearn.metrics import r2_score

# Actual values
actual = y_test

# Predicted values
predicted = y_pred

# Calculate the R2 score
r2 = r2_score(actual, predicted)

print("R2 score:", r2)
# Out:
# R2 score: 0.9869085084244353

# %%
# Plotting the R2 score
fig, ax = plt.subplots()
ax.barh(0, r2, color='skyblue')
ax.set_xlim([-1, 1])
ax.set_yticks([])
ax.set_xlabel('R2 Score')
ax.set_title('R2 Score')

# Adding the R2 score value on the bar
ax.text(r2, 0, f'{r2:.2f}', va='center', color='black')

plt.show()

# %%
plt.scatter(actual, predicted)
plt.plot([min(actual), max(actual)], [min(predicted), max(predicted)], 'r--')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.title(f'R2 Score: {r2:.2f}')
plt.show()
